# %%
import anatomist.api as ana
from soma.qt_gui.qtThread import QtThreadCall
from soma.qt_gui.qt_backend import Qt

a = ana.Anatomist()

from soma import aims
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# existing QApplication: 0
# QStandardPaths: XDG_RUNTIME_DIR not set, defaulting to '/tmp/runtime-ad279118'
# create qapp
# global modules: /casa/host/build/share/anatomist-5.2/python_plugins
# home   modules: /casa/home/.anatomist/python_plugins
# done
# Starting Anatomist.....
# config file : /casa/home/.anatomist/config/settings.cfg
# PyAnatomist Module present
# PythonLauncher::runModules()
# loading module simple_controls
# loading module save_resampled
# loading module selection
# loading module bsa_proba
# loading module modelGraphs
# loading module profilewindow
# loading module ana_image_math
# loading module paletteViewer
# loading module foldsplit
# loading module anacontrolmenu
# loading module gradientpalette
# loading module palettecontrols
# loading module meshsplit
# loading module volumepalettes
# loading module gltf_io
# loading module infowindow
# loading module histogram
# loading module statsplotwindow
# loading module valuesplotwindow
# all python modules loaded
# Anatomist started.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
import umap
import os

# %% [markdown]
# ### In this example, the embeddings are generated from a Barlow Twin model trained on the Left CINGULATE region on UKB for the UKB and HCP datasets.
#
#  -For the HCP dataset, the associated buckets can be found in:
#
# /neurospin/dico/data/deep_folding/current/datasets/hcp/crops/2mm/CINGULATE/mask/Lbuckets
#
#  -For the UKB dataset, the buckets are not generated yet, but it would be found in:
#
# /neurospin/dico/data/deep_folding/current/datasets/UkBioBank/crops/2mm/CINGULATE/mask/Lbuckets

# %% [markdown]
# ### Load your data

# %%
embeddings_UKB = pd.read_csv('/neurospin/dico/data/deep_folding/current/models/Champollion_V0/SC-sylv_right/11-43-38_3/ukb40_random_epoch100_embeddings/full_embeddings.csv', index_col=0)
labelled_CS = pd.read_csv('/neurospin/dico/data/deep_folding/current/datasets/UkBioBank40/CSLabel/interrupted_CS_labelled.csv')

list_problem = [
'sub-3716267',
'sub-5417598',
'sub-5472164',
'sub-5894417',
'sub-1703355',
'sub-4271898',
]

list_interrupted_CS = labelled_CS[labelled_CS.Interruption==1].ID.to_list()
list_interrupted = ['0' if i not in list_interrupted_CS else '1' for i in embeddings_UKB.index]
list_color = ['g' if i not in list_interrupted_CS else 'r' for i in embeddings_UKB.index]
list_size = [0.3 if i not in list_interrupted_CS else 30 for i in embeddings_UKB.index]
list_label = ['0' if i not in list_interrupted_CS else '1' for i in embeddings_UKB.index]
embeddings_UKB.head()
# Out:
#                   dim1       dim2       dim3       dim4        dim5  \
# ID
# sub-1000021 -37.629620   6.583590  29.279840 -16.611984  -30.081190
# sub-1000325  11.934219  11.355382 -13.496794 -38.996407   14.297873
# sub-1000458 -25.394463   4.755465 -22.513622 -25.682335  -67.619896
# sub-1000575 -25.367662 -23.005732 -30.035063  36.237038 -103.579190
# sub-1000606 -35.599197  -2.058082  26.222765  -3.495081  -49.495464
#
#                   dim6       dim7       dim8       dim9      dim10  ...  \
# ID                                                                  ...
# sub-1000021 -24.476210  11.042302  -6.784241  19.132568  10.150197  ...
# sub-1000325  -5.811631   6.174108 -45.331050   9.762536  44.107750  ...
# sub-1000458 -18.027046 -30.610876  51.657852 -18.840885  -7.459018  ...
# sub-1000575  -9.643719   4.125421  34.603440  19.479185 -13.243917  ...
# sub-1000606  -3.061627 -14.236676  -3.899254 -15.054834  50.399190  ...
#
#                 dim247     dim248     dim249      dim250     dim251  \
# ID
# sub-1000021  -2.848078  11.085325 -12.354747  -76.037210  -8.468971
# sub-1000325   4.212949   6.075599 -36.018467 -134.833560  26.447592
# sub-1000458  -9.459454  -0.912658  32.695583   12.509913  10.790437
# sub-1000575  20.220034  -5.049628   4.961305  -25.468930  25.991018
# sub-1000606   8.652889  27.369568  34.453293  -73.026400  40.409150
#
#                 dim252     dim253     dim254     dim255     dim256
# ID
# sub-1000021 -29.602938 -24.906027 -16.344492   7.703534  -1.050617
# sub-1000325 -35.490543   4.641970  -4.289551 -58.478560 -31.515226
# sub-1000458 -25.991050 -39.407890 -13.558734  47.675068  -0.354762
# sub-1000575   3.052118 -73.673270   6.855866  30.889896  43.402153
# sub-1000606  28.420736 -51.241203  17.027500  -0.707319 -20.734170
#
# [5 rows x 256 columns]

# %% [markdown]
# ### 2D UMAP

# %%
reducer2D = umap.UMAP(densmap=True, dens_lambda=10)
reducer2D.fit(embeddings_UKB)
bdd_2D_UKB = reducer2D.transform(embeddings_UKB)
# Out:
# /casa/home/.local/lib/python3.10/site-packages/numba/np/ufunc/parallel.py:371: NumbaWarning: The TBB threading layer requires TBB version 2021 update 6 or later i.e., TBB_INTERFACE_VERSION >= 12060. Found TBB_INTERFACE_VERSION = 12050. The TBB threading layer is disabled.
#   warnings.warn(problem)

# %%
bdd_2D_UKB = pd.DataFrame(bdd_2D_UKB, columns=['Dim 1', 'Dim 2'])
bdd_2D_UKB['Dataset'] = 'UkBioBank'
bdd_2D_UKB['ID'] = embeddings_UKB.index
bdd_2D_UKB['Interruption'] = list_interrupted
bdd_2D_UKB.head()
# Out:
#        Dim 1     Dim 2    Dataset           ID Interruption
# 0   5.418256  3.340750  UkBioBank  sub-1000021            0
# 1   2.152718  3.027361  UkBioBank  sub-1000325            0
# 2   8.669504  5.931939  UkBioBank  sub-1000458            0
# 3  11.337758  3.280071  UkBioBank  sub-1000575            0
# 4   8.659309  4.655163  UkBioBank  sub-1000606            0

# %% [markdown]
# ### Plot it in the notebook or write a html file

# %%
subject_id_list = []
dataset_name_list = []

# %%
# Create the scatter plot using plotly express
fig = px.scatter(
    bdd_2D_UKB, x='Dim 1', y='Dim 2', 
    color='Interruption',
    title='CS interruption UKB',
    labels={'0': 'dim 1', '1': 'dim 2'},
    hover_data= ['Dataset', 'ID'],
    opacity=0.5,
    width=800, height=600
)

# Convert the figure to a FigureWidget
f = go.FigureWidget(fig)

# Define the callback function
def click_callback(trace, points, selector):
    for trace_index in range(len(f.data)):
        if trace_index == points.trace_index:
            customdata = f.data[trace_index].customdata
            for i in points.point_inds:
                point_dataset, point_id = customdata[i]
                print(f"Clicked point ID: {point_id}, Dataset: {point_dataset}")
                subject_id_list.append(point_id)
                dataset_name_list.append(point_dataset)

# Attach the callback to the on_click event for all traces
for trace in f.data:
    trace.on_click(click_callback)

# Display the figure widget
f
# Out:
# FigureWidget({
#     'data': [{'customdata': array([['UkBioBank', 'sub-1000021'],
#                                    ['UkBioBank', 'sub-1000325'],
#                                    ['UkBioBank', 'sub-1000458'],
#                                    ...,
#                                    ['UkBioBank', 'sub-6024150'],
#                                    ['UkBioBank', 'sub-6024379'],
#                                    ['UkBioBank', 'sub-6024754']], dtype=object),
#               'hovertemplate': ('Interruption=0<br>Dim 1=%{x}<b' ... '{customdata[1]}<extra></extra>'),
#               'legendgroup': '0',
#               'marker': {'color': '#636efa', 'opacity': 0.5, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': '0',
#               'showlegend': True,
#               'type': 'scattergl',
#               'uid': 'd166e282-286a-48b6-93d4-71c74c8c94f1',
#               'x': array([5.418256 , 2.1527178, 8.669504 , ..., 4.8669534, 8.700199 , 7.5958586],
#                          dtype=float32),
#               'xaxis': 'x',
#               'y': array([ 3.3407505,  3.0273612,  5.9319386, ...,  2.2778044, -1.6511627,
#                            5.7814975], dtype=float32),
#               'yaxis': 'y'},
#              {'customdata': array([['UkBioBank', 'sub-1015120'],
#                                    ['UkBioBank', 'sub-1037052'],
#                                    ['UkBioBank', 'sub-1060820'],
#                                    ...,
#                                    ['UkBioBank', 'sub-5949398'],
#                                    ['UkBioBank', 'sub-5984646'],
#                                    ['UkBioBank', 'sub-5993265']], dtype=object),
#               'hovertemplate': ('Interruption=1<br>Dim 1=%{x}<b' ... '{customdata[1]}<extra></extra>'),
#               'legendgroup': '1',
#               'marker': {'color': '#EF553B', 'opacity': 0.5, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': '1',
#               'showlegend': True,
#               'type': 'scattergl',
#               'uid': 'f9f1b893-ddfb-449e-8a94-67b15ee9f934',
#               'x': array([3.1892486, 4.082435 , 3.6551933, ..., 1.4251156, 8.258589 , 1.5658222],
#                          dtype=float32),
#               'xaxis': 'x',
#               'y': array([ 6.0803204 , 12.812532  ,  4.7077003 , ...,  0.82352793,  9.0223675 ,
#                            6.6360683 ], dtype=float32),
#               'yaxis': 'y'}],
#     'layout': {'height': 600,
#                'legend': {'title': {'text': 'Interruption'}, 'tracegroupgap': 0},
#                'template': '...',
#                'title': {'text': 'CS interruption UKB'},
#                'width': 800,
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'Dim 1'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'Dim 2'}}}
# })
# Clicked point ID: sub-2660955, Dataset: UkBioBank
# Clicked point ID: sub-1743563, Dataset: UkBioBank
# Clicked point ID: sub-4760288, Dataset: UkBioBank
# Clicked point ID: sub-1094033, Dataset: UkBioBank
# Clicked point ID: sub-1568981, Dataset: UkBioBank
# Clicked point ID: sub-3416453, Dataset: UkBioBank
# Clicked point ID: sub-1496375, Dataset: UkBioBank
# Clicked point ID: sub-3878185, Dataset: UkBioBank
# Clicked point ID: sub-4381871, Dataset: UkBioBank
# Clicked point ID: sub-5859618, Dataset: UkBioBank
# Clicked point ID: sub-3630660, Dataset: UkBioBank
# Clicked point ID: sub-5855872, Dataset: UkBioBank
# Clicked point ID: sub-5626543, Dataset: UkBioBank
# Clicked point ID: sub-1697914, Dataset: UkBioBank
# Clicked point ID: sub-5360657, Dataset: UkBioBank
# Clicked point ID: sub-3622369, Dataset: UkBioBank
# Clicked point ID: sub-2660955, Dataset: UkBioBank
# Clicked point ID: sub-1654153, Dataset: UkBioBank
# Clicked point ID: sub-4861863, Dataset: UkBioBank
# Clicked point ID: sub-3541056, Dataset: UkBioBank
# Clicked point ID: sub-5347077, Dataset: UkBioBank
# Clicked point ID: sub-4950016, Dataset: UkBioBank
# Clicked point ID: sub-1748817, Dataset: UkBioBank
# Clicked point ID: sub-5462773, Dataset: UkBioBank
# Clicked point ID: sub-1299814, Dataset: UkBioBank

# %%
dataset = 'UkBioBank40'
region = "S.C.-sylv."
side = "R"

mm_skeleton_path = f'/neurospin/dico/data/deep_folding/current/datasets/{dataset}/crops/2mm/{region}/mask/{side}crops'

# %%
volume_files = []

for subject_id in set(subject_id_list):
    volume_path = f"{mm_skeleton_path}/{subject_id}_cropped_skeleton.nii.gz"
    
    if os.path.isfile(volume_path):
        vol = aims.read(volume_path)
        volume_files.append(vol)
    else:
        print(f"{volume_path} is not a correct path, or the .nii.gz doesn't exist")

block = a.createWindowsBlock(4) # number of columns
dic_windows = {}

for i, vol in enumerate(volume_files):
    dic_windows[f'a_vol{i}'] = a.toAObject(vol)
    #dic_windows[f'a_vol{i}'].setPalette(absoluteMode=True)
    dic_windows[f'rvol{i}'] = a.fusionObjects(objects=[dic_windows[f'a_vol{i}']], method='VolumeRenderingFusionMethod')
    dic_windows[f'rvol{i}'].releaseAppRef()
    dic_windows[f'wvr{i}'] = a.createWindow('3D', block=block) #geometry=[100+400*(i%3), 100+440*(i//3), 400, 400])
    dic_windows[f'wvr{i}'].addObjects(dic_windows[f'rvol{i}'])
# Out:
# no position could be read at 512, 284
# no position could be read at 411, 200
# no position could be read at 343, 209
# no position could be read at 358, 206
# no position could be read at 266, 145
